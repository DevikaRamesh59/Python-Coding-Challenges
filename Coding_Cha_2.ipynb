# %% [markdown]
# ### **Project Title: Retail Inventory Manager**

# %% [markdown]
# ### **Create a Tuple with fixed Product categories like Stationary, Electronics and Clothing**

# %%
### Create a tuple with fixed products categories like electronics, stationery ,and clothing.
Product_Category=("Electronics","Stationery","Clothing")
### Create a list of products that can be updated dynamically.
Product_List=["TV","Fridge","Jeans","Pencil","Shirt","Sharpner"]
## As the user to enter a new product and add it to the list
Product_List.append("Washing_Machine")
print(Product_List)
Product_List.append("Pen")
Product_List
## As the user to input The index of a product to remove it from the list
user=int(input("Enter the index of a product to be removed"))
Remove_product=Product_List.pop(user)
print(Product_List)

## Display the final list of products and the product categories.
print("Final list of product", Product_List)
print("Final list of product category", Product_Category)
# Out:
# ['TV', 'Fridge', 'Jeans', 'Pencil', 'Shirt', 'Sharpner', 'Washing_Machine']
# Enter the index of a product to be removed4
# ['TV', 'Fridge', 'Jeans', 'Pencil', 'Sharpner', 'Washing_Machine', 'Pen']
# Final list of product ['TV', 'Fridge', 'Jeans', 'Pencil', 'Sharpner', 'Washing_Machine', 'Pen']
# Final list of product category ('Electronics', 'Stationery', 'Clothing')
