# %% [markdown]
# ### **List Methods And Slicing**

# %% [markdown]
# ### **Project Title: Contact Dictionary Scenario**

# %%
### Create a 2D list where each row holds a contact's name ,phone number and email address.

Contact_list=[["Robert",9943265789,"rob.ka@gamil.com"],["James",6754329892,"james.vin@icload.com"],["Antony",9865794989,"ant.v@yahoo.com"]]
Contact_list

## Allow the user to add a new contact'
Contact_list.append(["Princy",897653325,"Princ.j@gmail.com"])
Contact_list

##Remove the last item
Contact_list.pop()

### Get new item From Users using input() and add those items to the list Sort the list in ascending order based on any values
C1=input("Enter your name")
C2=int(input("Enter your phone number"))
C3=input("Enter your email id")
Contact_list.append([C1,C2,C3])
Contact_list.sort()
Contact_list
# Out:
# Enter your nameShwetha
# Enter your phone number8978664033
# Enter your email idshwe24@gmail.com
# [['Antony', 9865794989, 'ant.v@yahoo.com'],
#  ['James', 6754329892, 'james.vin@icload.com'],
#  ['Robert', 9943265789, 'rob.ka@gamil.com'],
#  ['Shwetha', 8978664033, 'shwe24@gmail.com']]
